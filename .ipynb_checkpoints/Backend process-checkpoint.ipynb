# %%
import pandas as pd 
from datetime import datetime, timedelta
import folium
from folium.plugins import HeatMapWithTime
import numpy as np
from folium.plugins import HeatMap

import io
from PIL import Image

import urllib.request

from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt

from shapely.geometry import Polygon, Point
import json
from shapely.geometry import shape, GeometryCollection
import matplotlib.dates as dates

import os
import imageio

# %matplotlib inline

# %% [markdown]
# # Read data

# %%
confirm_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vSr2xYotDgnAq6bqm5Nkjq9voHBKzKNWH2zvTRx5LU0jnpccWykvEF8iB_0g7Tzo2pwzkTuM3ETlr_h/pub?gid=0&range=A2:ZZ&output=csv'
highrisk_url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vT6aoKk3iHmotqb5_iHggKc_3uAA901xVzwsllmNoOpGgRZ8VAA3TSxK6XreKzg_AUQXIkVX5rqb0Mo/pub?gid=0&range=A2:ZZ&output=csv'

str_today = datetime.now().strftime("%Y-%m-%d")

case_fname = './data/' + str_today + 'case.csv'
highrisk_fname = './data/' + str_today + 'location.csv'

f_case = open(case_fname, "w", encoding='UTF-8')
f_highrisk = open(highrisk_fname, "w", encoding='UTF-8')

with urllib.request.urlopen(highrisk_url) as f:
    html = f.read().decode('utf-8')
    f_highrisk.write(html)

with urllib.request.urlopen(confirm_url) as f:
    html = f.read().decode('utf-8')
    f_case.write(html)
    
f_case.close()
f_highrisk.close()

# %%
# create output directory
output_path = "./image/" + str_today
if not os.path.exists(output_path):
    os.mkdir(output_path)

# %% [markdown]
# # Read in case file and danger zone file

# %%
data_master = pd.read_csv(case_fname, encoding='utf8') 
data_loc = pd.read_csv(highrisk_fname, encoding='utf8')

# %%
district_list = ["Central and Western", "Eastern", "Southern", "Wan Chai", 
            "Kowloon City", "Kwun Tong", "Sham Shui Po", "Wong Tai Sin",
            "Yau Tsim Mong", "Islands", "Kwai Tsing", "North",
            "Sai Kung", "Sha Tin", "Tai Po", "Tsuen Wan",
            "Tuen Mun", "Yuen Long"]

district_zh_list = ["中西區", "東區", "南區", "灣仔區", "九龍城區", "觀塘區", 
                  "深水埗區", "黃大仙區", "油尖旺區", "離島區", "葵青區", "北區",
                  "西貢區", "沙田區", "大埔區", "荃灣區", "屯門區", "元朗區"]

district_polys = []

for district in district_list:
    filename = "geodata/" + district + ".txt"
    with open(filename) as f:
        features = json.load(f)
        district_polys.append(shape(features))
        
loc_center = {
    "Hong Kong": [22.350627,114.1849161],
    "Central and Western": [22.2748365,114.14873730393252],
    "Eastern": [22.2730777,114.23359377341592],
    "Southern": [22.2192627,114.22522984854672],
    "Wan Chai": [22.27394695,114.18174874679013],
    "Kowloon City": [22.32179955,114.18859418638175],
    "Kwun Tong": [22.308648599999998,114.22766104671223],
    "Sham Shui Po": [22.33125395,114.15932119657994],
    "Wong Tai Sin": [22.34432185,114.20215028440833],
    "Yau Tsim Mong": [22.3074036,114.16552591155013],
    "Islands": [22.23007565,113.98678546827477],
    "Kwai Tsing": [22.34101175,114.10428534268473],
    "North": [22.516949349999997,114.21359265126003],
    "Sai Kung": [22.3070096,114.37134533899689],
    "Sha Tin": [22.39157275,114.20809762908664],
    "Tai Po": [22.480971150000002,114.30410296970287],
    "Tsuen Wan": [22.364986950000002,114.07768836682578],
    "Tuen Mun": [22.3788404,113.95282979560184],
    "Yuen Long": [22.45729575,114.02131879795456],    
}


loc_zoom = {
    "Hong Kong": 11,
    "Central and Western": 14,
    "Eastern": 14,
    "Southern": 13,
    "Wan Chai": 14,
    "Kowloon City": 13,
    "Kwun Tong": 14,
    "Sham Shui Po": 14,
    "Wong Tai Sin": 14,
    "Yau Tsim Mong": 14,
    "Islands": 12,
    "Kwai Tsing": 13,
    "North": 12, 
    "Sai Kung": 12,
    "Sha Tin": 13,
    "Tai Po": 12,
    "Tsuen Wan": 13,
    "Tuen Mun": 13,
    "Yuen Long": 13,    
}

# %%
def findDistrict(point):
    
    for i, poly in enumerate(district_polys):
        if poly.contains(point):
            return i
    
    return -1

# %%
# supplement real district
data_loc['real_distict'] = 'other'
data_loc['real_distict_zh'] = 'other'

for index, row in data_loc.iterrows():
    district_num = findDistrict(Point(row['lng'], row['lat']))
    district_en = district_list[district_num]
    district_zh = district_zh_list[district_num]
    data_loc.at[index, 'real_distict'] = district_en
    data_loc.at[index, 'real_distict_zh'] = district_zh

# %%
df_by_date = data_master.loc[:, ['confirmation_date']] 
by_date = df_by_date.groupby('confirmation_date').size()
by_date.index = pd.to_datetime(by_date.index)

fig, ax = plt.subplots(figsize=(20,10))
ax.plot_date(by_date.index.tolist(), by_date, '-')
ax.xaxis.set_minor_locator(dates.WeekdayLocator(byweekday=(0),
                                                interval=1))
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))
#ax.xaxis.grid(True, which="minor")
#ax.yaxis.grid()
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n\n%b\n%Y'))
#plt.tight_layout()
#plt.figure()
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
plt.title(u'香港每日確診人數', fontsize=20)

# save image
fig1 = plt.gcf()
output_path = "./image/" + str_today + "/day_case.png"
fig1.savefig(output_path, dpi=100)

plt.show()

# %%
# Total case
cum_date = by_date.cumsum()
cum_date.index = pd.to_datetime(cum_date.index)

fig, ax = plt.subplots(figsize=(20,10))
ax.plot_date(cum_date.index.tolist(), cum_date, '-')
ax.xaxis.set_minor_locator(dates.WeekdayLocator(byweekday=(0),
                                                interval=1))
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))
#ax.xaxis.grid(True, which="minor")
#ax.yaxis.grid()
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n\n%b\n%Y'))
#plt.tight_layout()
#plt.figure()
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
plt.title(u'香港累計確診人數', fontsize=20)

# save image
fig1 = plt.gcf()
output_path = "./image/" + str_today + "/cumulative_case.png"
fig1.savefig(output_path, dpi=100)

plt.show()

# %%
# current admission state (not discharge, death and no admission)
is_admission = (data_master['status'] != 'discharged') & (data_master['status'] != 'deceased')  & (data_master['status'] != 'no_admission')
data_filter = data_master[is_admission]
df_status_group = data_filter.loc[:, ['status_zh']]
status_case = df_status_group.groupby('status_zh').size()

colorMap = {"危殆": "red", "嚴重": "dodgerblue", "穩定": "forestgreen", "待入院": "yellow"}
colors = [colorMap[key] for key in status_case.index] 

fig, ax = plt.subplots(figsize=(5,5))
plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
ax = status_case.plot.pie(legend=True,  autopct='%1.1f%%', colors = colors , title="入院嚴重程度")
ax.get_legend().set_bbox_to_anchor((1,0.5))


# save image
fig1 = plt.gcf()
output_path = "./image/" + str_today + "/hospital_case.png"
fig1.savefig(output_path, dpi=100)

plt.show()

# %% [markdown]
# # recent age group

# %%
# get daily
# cum sum to 7 and 14 then done
day14 = datetime.today() - timedelta(days=14)
day7 = datetime.today() - timedelta(days=7)

day14_str = day14.strftime("%Y-%m-%d")
day7_str = day7.strftime("%Y-%m-%d")
today_str = datetime.today().strftime("%Y-%m-%d")

bins = np.arange(1, 10) * 10

# today
filter_criteria = (data_master['confirmation_date'] == today_str)
data_district = data_master[filter_criteria]
data_district['age_category'] = np.digitize(data_district.age, bins, right=True)
counts_today = data_district.groupby(['age_category', 'gender']).age.count().unstack().fillna(0)

for i in bins:
    if not i in counts_today.index:
        
counts.plot(kind='bar', stacked=True)
# Out:
# /home/ymlai/anaconda3/envs/hkcovidenv/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ymlai/anaconda3/envs/hkcovidenv/lib/python3.6/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/ymlai/anaconda3/envs/hkcovidenv/lib/python3.6/site-packages/ipykernel_launcher.py:37: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-62917eefa74b> in <module>
#      37 ax = plt.subplot(111)
#      38 w=0.3
# ---> 39 ax.bar(bins-w, counts_today, width=w, color='b', align='center', stacked=True)
#      40 ax.bar(bins, counts_7, width=w, color='b', align='center', stacked=True)
#      41 ax.bar(bins+w, counts_14, width=w, color='b', align='center', stacked=True)
#
# ~/anaconda3/envs/hkcovidenv/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/hkcovidenv/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2430         x, height, width, y, linewidth = np.broadcast_arrays(
#    2431             # Make args iterable too.
# -> 2432             np.atleast_1d(x), height, width, y, linewidth)
#    2433
#    2434         # Now that units have been converted, set the tick locations.
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~/anaconda3/envs/hkcovidenv/lib/python3.6/site-packages/numpy/lib/stride_tricks.py in broadcast_arrays(subok, *args)
#     256     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     257
# --> 258     shape = _broadcast_shape(*args)
#     259
#     260     if all(array.shape == shape for array in args):
#
# ~/anaconda3/envs/hkcovidenv/lib/python3.6/site-packages/numpy/lib/stride_tricks.py in _broadcast_shape(*args)
#     187     # use the old-iterator because np.nditer does not handle size 0 arrays
#     188     # consistently
# --> 189     b = np.broadcast(*args[:32])
#     190     # unfortunately, it cannot handle 32 or more arguments directly
#     191     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %% [markdown]
# # Danger zone

# %%
def loc_time_range(center, df, start, end, zoom=11):
 
    is_last_14 = (df['end_date'] >= start.strftime("%Y-%m-%d")) & (df['end_date'] <= end.strftime("%Y-%m-%d")) & df['lat'].notnull()& df['lng'].notnull() 
    last_14_df = df[is_last_14]

    df1 = last_14_df[['lat', 'lng']].values.tolist()
    
    fmap = folium.Map(center, zoom_start=zoom, )
    fmap.add_child(HeatMap(data=df1, radius=10, blur=10))
    
    return fmap

def adjustedRadius(currentZoom):
    currentZoom = currentZoom -1
    if (currentZoom == 8):
        radius = 6
    elif (currentZoom == 10):
        radius = 8
    elif (currentZoom == 11):
        radius = 10
    elif (currentZoom == 12):
        radius = 12
    elif (currentZoom == 13):
        radius = 14
    elif (currentZoom == 14):
        radius = 16
    elif (currentZoom == 15):
        radius = 18
        
    return radius

def drawHeatMap(df, center, title, json_url, zoom=11):

    df1 = df[['lat', 'lng']].values.tolist()
    
    fmap = folium.Map(center, zoom_start=zoom, )
    
    if json_url is not None:
        fmap.add_child(folium.GeoJson(json_url, name='geojson' )) #.add_to(fmap)
    
    fmap.add_child(HeatMap(data=df1, radius=adjustedRadius(zoom), blur=6))
    
    fmap.caption = title
    
    title_html = '<h3 align="center" style="font-size:20px"><b>' + title + '</b></h3>'
    fmap.get_root().html.add_child(folium.Element(title_html))

    return fmap

def drawHeatMapWithTime(df, date, center, title, json_url, zoom=11):
    df1 = []
    for d in df:
        df1.append(d[['lat', 'lng']].values.tolist())
    
    fmap = folium.Map(center, zoom_start=zoom, )
    
    if json_url is not None:
        fmap.add_child(folium.GeoJson(json_url, name='geojson' )) #.add_to(fmap)
    
    fmap.add_child(HeatMapWithTime(data=df1, index=date, radius=5))
    
    fmap.caption = title
    
    title_html = '<h3 align="center" style="font-size:20px"><b>' + title + '</b></h3>'
    fmap.get_root().html.add_child(folium.Element(title_html))

    return fmap

def filter_distict_time_range(df, district, start, end):
 
    is_last_14 = (df['end_date'] >= start.strftime("%Y-%m-%d")) & (df['end_date'] <= end.strftime("%Y-%m-%d")) & df['lat'].notnull()& df['lng'].notnull() 
    if district is not None:
        is_last_14 = (df["real_distict"] == district) & is_last_14
    
    last_14_df = df[is_last_14]
    
    return last_14_df

def parse_zhch(s):
    return str(str(s).encode('ascii' , 'xmlcharrefreplace'))[2:-1]

def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n+1)

# %%
day14 = datetime.today() - timedelta(days=14)

hk_filter = filter_distict_time_range(data_loc, None, day14, datetime.today())

hk_center_pos = loc_center["Hong Kong"]
# print(hk_center_pos)
# fmap = loc_time_range(hk_center_pos, data_loc, day14, datetime.today())
title = parse_zhch("香港新冠肺炎危險地區 (過往14天): ") + str_today 
fmap = drawHeatMap(hk_filter, hk_center_pos, title, None, 11)

fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# save today image
img_data = fmap._to_png()
img = Image.open(io.BytesIO(img_data))
img.save("image/" + str_today + '/zone14.png')

# %% [markdown]
# # Animation for 7 days

# %%
range_start = datetime.today() -  timedelta(days=7)
range_end = datetime.today()

for end_date in daterange(range_start, range_end):

    day14 = end_date - timedelta(days=14)
    str_endday = end_date.strftime("%Y-%m-%d")

    hk_filter = filter_distict_time_range(data_loc, None, day14, end_date)

    hk_center_pos = loc_center["Hong Kong"]
    # print(hk_center_pos)
    # fmap = loc_time_range(hk_center_pos, data_loc, day14, datetime.today())
    title = parse_zhch("香港新冠肺炎危險地區 (過往14天): ") + str_endday 
    fmap = drawHeatMap(hk_filter, hk_center_pos, title, None, 11)

    # save today image
    img_data = fmap._to_png()
    img = Image.open(io.BytesIO(img_data))
    img.save("image/" + str_today + "/" + str_endday + '-animation.png')

# %%
# use another method call HeatMapWithTime 
range_start = datetime.today() -  timedelta(days=7)
range_end = datetime.today()

data = []
date = []

for end_date in daterange(range_start, range_end):
    day14 = end_date - timedelta(days=14)
    str_endday = end_date.strftime("%Y-%m-%d")
    
    data.append(filter_distict_time_range(data_loc, None, day14, end_date))
    date.append(str_endday)
    
hk_center_pos = loc_center["Hong Kong"]
# print(hk_center_pos)
# fmap = loc_time_range(hk_center_pos, data_loc, day14, datetime.today())
title = parse_zhch("香港新冠肺炎危險地區 (過往14天): ") + str_today 
fmap = drawHeatMapWithTime(data, date, hk_center_pos, title, None, 11)

fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # District specific

# %%
# create all the district 
for dis in district_list:
    output_path = "./image/" + str_today + "/" + dis
    if not os.path.exists(output_path):
        os.mkdir(output_path)

# %%
# find start date and end date
loc_start_date = data_loc['start_date'].dropna().min()
loc_end_date = data_loc['start_date'].dropna().max()

print(loc_start_date, loc_end_date)
# Out:
# 2019-09-19 2020-12-25

# %%
# Demo a district
cur_district = "Tsuen Wan"
cur_district_idx =15

# patient increase (daily and cum)
in_district = (data_master['citizenship_district_en']  == cur_district) 
patient_filter = data_master[in_district]

# danger area graph (Last 14 day)
zone_district = (data_loc['real_distict'] == cur_district)
loc_filter = data_loc[zone_district]

# %%
df_by_date = patient_filter.loc[:, ['confirmation_date']] 
by_date = df_by_date.groupby('confirmation_date').size()
by_date.index = pd.to_datetime(by_date.index)

fig, ax = plt.subplots(figsize=(20,10))
ax.plot_date(by_date.index.tolist(), by_date, '-')
ax.xaxis.set_minor_locator(dates.WeekdayLocator(byweekday=(0),
                                                interval=1))
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))
#ax.xaxis.grid(True, which="minor")
#ax.yaxis.grid()
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n\n%b\n%Y'))
#plt.tight_layout()
#plt.figure()

plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
plt.title(district_zh_list[cur_district_idx] + u'每日確診人數', fontsize=20)

# save image
fig1 = plt.gcf()
output_path = "./image/" + str_today + "/" + cur_district + "/day_case.png"
fig1.savefig(output_path, dpi=100)

plt.show()

# %%
# Total case
cum_date = by_date.cumsum()
cum_date.index = pd.to_datetime(cum_date.index)

fig, ax = plt.subplots(figsize=(20,10))
ax.plot_date(cum_date.index.tolist(), cum_date, '-')
ax.xaxis.set_minor_locator(dates.WeekdayLocator(byweekday=(0),
                                                interval=1))
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))
#ax.xaxis.grid(True, which="minor")
#ax.yaxis.grid()
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n\n%b\n%Y'))
#plt.tight_layout()
#plt.figure()

plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
plt.title(district_zh_list[cur_district_idx] + u'累計確診人數', fontsize=20)

# save image
fig1 = plt.gcf()
output_path = "./image/" + str_today + "/" + cur_district + "/cumulative_case.png"
fig1.savefig(output_path, dpi=100)

plt.show()

# %% [markdown]
# # All district plot with hightlighted line chart

# %%
# Total case

cum_dates = []
for district in district_list:
    in_district = (data_master['citizenship_district_en']  == district) 
    patient_filter = data_master[in_district]
    df_by_date = patient_filter.loc[:, ['confirmation_date']] 
    by_date = df_by_date.groupby('confirmation_date').size()
    by_date.index = pd.to_datetime(by_date.index)
    cum_date = by_date.cumsum()
    cum_date.index = pd.to_datetime(cum_date.index)
    
    cum_dates.append(cum_date)

fig, ax = plt.subplots(figsize=(20,10))

for idx, cd in enumerate(cum_dates):
    if cur_district_idx == idx:
        ax.plot_date(cd.index.tolist(), cd, '-', color='orange', linewidth=4, alpha=1)
    else:
        ax.plot_date(cd.index.tolist(), cd, '-', color='grey', linewidth=1, alpha=0.3)
    
ax.xaxis.set_minor_locator(dates.WeekdayLocator(byweekday=(0),
                                                interval=1))
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))
#ax.xaxis.grid(True, which="minor")
#ax.yaxis.grid()
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n\n%b\n%Y'))
#plt.tight_layout()
#plt.figure()

plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
plt.title(district_zh_list[cur_district_idx] + u'累計確診人數', fontsize=20)

# save image
fig1 = plt.gcf()
output_path = "./image/" + str_today + "/" + cur_district + "/cumulative_case.png"
fig1.savefig(output_path, dpi=100)

plt.show()

# %%
# rolling 14 day for danger zone
df_by_date = loc_filter.loc[:, ['end_date']] 
by_date = df_by_date.groupby('end_date').size()
by_date.index = pd.to_datetime(by_date.index)
#exp
by_date_exp = pd.Series(index=pd.date_range(loc_start_date, loc_end_date), data=0)

for i,val in by_date.iteritems():
    by_date_exp[i] = val  
    
by_date_14 = by_date_exp.rolling(window=14).sum()
by_date_14 = by_date_14.dropna()

fig, ax = plt.subplots(figsize=(20,10))
ax.plot_date(by_date_14.index.tolist(), by_date_14, '-')
ax.xaxis.set_minor_locator(dates.WeekdayLocator(byweekday=(0),
                                                interval=1))
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))
#ax.xaxis.grid(True, which="minor")
#ax.yaxis.grid()
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n\n%b\n%Y'))
#plt.tight_layout()
#plt.figure()

plt.rcParams['font.sans-serif'] = ['Noto Sans CJK JP']
plt.title(district_zh_list[cur_district_idx] + u'危險地區數目', fontsize=20)

# save image
fig1 = plt.gcf()
output_path = "./image/" + str_today + "/" + cur_district + "/zone14d.png"
fig1.savefig(output_path, dpi=100)

plt.show()

# %%
hk_center_pos = loc_center[cur_district]
data_loc_cw = filter_distict_time_range(data_loc, cur_district, day14, datetime.today())
title = parse_zhch(district_zh_list[cur_district_idx] +  "新冠肺炎危險地區 (過往14天): ") + str_today 
fmap = drawHeatMap(data_loc_cw, hk_center_pos, title, "geodata/" + cur_district + ".txt", loc_zoom[cur_district])

fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# save today image
img_data = fmap._to_png()
img = Image.open(io.BytesIO(img_data))
img.save("image/" + str_today + "/" + cur_district + '/zone14.png')

# %% [markdown]
# # Animation for last 7 days

# %%
range_start = datetime.today() -  timedelta(days=7)
range_end = datetime.today()

for end_date in daterange(range_start, range_end):

    day14 = end_date - timedelta(days=14)
    str_endday = end_date.strftime("%Y-%m-%d")

    hk_center_pos = loc_center[cur_district]
    data_loc_cw = filter_distict_time_range(data_loc, cur_district, day14, datetime.today())
    title = parse_zhch(district_zh_list[cur_district_idx] +  "新冠肺炎危險地區 (過往14天): ") + str_today 
    fmap = drawHeatMap(data_loc_cw, hk_center_pos, title, "geodata/" + cur_district + ".txt", loc_zoom[cur_district])

    # save today image
    img_data = fmap._to_png()
    img = Image.open(io.BytesIO(img_data))
    img.save("image/" + str_today + "/" + cur_district + "/" + str_endday + '-animation.png')

# %% [markdown]
# # Rank by district last week and last 2 week

# %%
# get daily
# cum sum to 7 and 14 then done
day14 = datetime.today() - timedelta(days=14)
day7 = datetime.today() - timedelta(days=7)

day14_str = day14.strftime("%Y-%m-%d")
day7_str = day7.strftime("%Y-%m-%d")
today_str = datetime.today().strftime("%Y-%m-%d")


filter_criteria = (data_master['confirmation_date'] == today_str)
data_district = data_master[filter_criteria]
df_by_date = data_district.loc[:, ['citizenship_district_en']] 
by_date = df_by_date.groupby('citizenship_district_en').size()

output_path = "image/" + str_today + "/today.csv"
today_rank = by_date
by_date.to_csv(output_path, index=True)

# 7 days
filter_criteria =  (data_master['confirmation_date'] > day7_str)
data_district = data_master[filter_criteria]
df_by_date = data_district.loc[:, ['citizenship_district_en']] 
by_date = df_by_date.groupby('citizenship_district_en').size()

output_path = "image/" + str_today + "/7days.csv"
day7_rank = by_date
by_date.to_csv(output_path, index=True)

# 14 days citizenship_district_en
filter_criteria =  (data_master['confirmation_date'] > day14_str)
data_district = data_master[filter_criteria]
df_by_date = data_district.loc[:, ['citizenship_district_en']] 
by_date = df_by_date.groupby('citizenship_district_en').size()

output_path = "image/" + str_today + "/14days.csv"
day14_rank = by_date
by_date.to_csv(output_path, index=True)

#

# %%
today_rank.name = "today"
day7_rank.name = "7 days cumulative"
day14_rank.name = "14 days cumulative"
rank_concat= pd.concat([today_rank, day7_rank, day14_rank], axis=1)
output_path = "image/" + str_today + "/rank_concat.csv"
rank_concat.to_csv(output_path, index=True)

# %%
rank_concat2 = rank_concat.filter(items = district_list, axis=0)
sum_concat = rank_concat.sum(axis = 0, skipna=True)
sum_concat2 = rank_concat2.sum(axis=0, skipna=True)
other_concat = sum_concat - sum_concat2
other_concat.name="Others"
rank_concat2.append(other_concat)
#rank_concat2
# Out:
#                today  7 days cumulative  14 days cumulative
# Eastern          NaN               12.0                27.0
# Southern         NaN                3.0                13.0
# Wan Chai         NaN                4.0                18.0
# Kowloon City     NaN               31.0                70.0
# Kwun Tong        NaN               10.0                49.0
# Sham Shui Po     NaN               27.0                75.0
# Wong Tai Sin     NaN               20.0                62.0
# Yau Tsim Mong    NaN               18.0                37.0
# Islands          NaN                1.0                 6.0
# Kwai Tsing       NaN                7.0                27.0
# North            NaN                2.0                 5.0
# Sai Kung         NaN                7.0                18.0
# Sha Tin          NaN                7.0                15.0
# Tai Po           NaN                4.0                 7.0
# Tsuen Wan        NaN                4.0                11.0
# Tuen Mun         NaN               18.0                30.0
# Yuen Long        NaN               25.0                46.0
# Others           0.0               47.0                85.0

# %%
# Total case export as json
# current admission state (not discharge, death and no admission)
deceased_count = 0
discharged_count= 0
hospitalize_count= 0
other_count= 0
is_deceased = data_master['status'] == 'deceased'
data_filter = data_master[is_deceased]
deceased_count = len(data_filter)

is_discharged = data_master['status'] == 'discharged'
data_filter = data_master[is_discharged]
discharged_count = len(data_filter)

is_hospitalize =(data_master['status'] != 'discharged') & (data_master['status'] != 'deceased')  & (data_master['status'] != 'no_admission')
data_filter = data_master[is_hospitalize]
hospitalize_count = len(data_filter)


is_other = data_master['status'] == 'no_admission'
data_filter = data_master[is_other]
other_count = len(data_filter)

print(deceased_count, discharged_count, hospitalize_count, other_count)
# Out:
# 158 8423 1387 30

# %%
dates
# Out:
# ['2020-12-24',
#  '2020-12-25',
#  '2020-12-26',
#  '2020-12-27',
#  '2020-12-28',
#  '2020-12-29',
#  '2020-12-30']
